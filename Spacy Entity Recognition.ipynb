# %%
import feedparser
# importing feedparser library

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
url = "https://news.google.?hl=en-IN&gl=IN&ceid=IN%3Aen"
# XML url to parse business news data

# %%
f = feedparser.parse(url)
# feedparser.parse extracts the required objects from the url

# %%
import pandas as pd

# %%
data = {}
# Creating an empty dictionary

# %%
for entry in f.entries:
    
    data.setdefault('title',[])
    data.setdefault('summary',[])
    data.setdefault('published',[])
    data.setdefault('link',[])
    data['title'].append(entry.title)
    data['summary'].append(entry.summary)
    data['published'].append(entry.published)
    data['link'].append(entry.link)
# Appending the required data to the empty dictionary

# %%
df = pd.DataFrame(data)
# Pushing the data to a dataframe

# %%
df
# Out:
#                                                 title  \
# 0   Top 10 things to know before the market opens ...
# 1   Isaac Newton made this blunder 300 years back ...
# 2   Stock Markets Live: Sensex, Nifty Hold Advance...
# 3   Markets seen flat ahead of US Fed meet; Tata M...
# 4   Ahead of Market: 12 things that will decide st...
# ..                                                ...
# 65  Stock Markets Today: Tesla earnings; Johnson c...
# 66  Maersk doubles full-year net profit guidance a...
# 67  The labor market is heating up as fewer people...
# 68  Stock market update: 69 stocks hit 52-week hig...
# 69  The psychology of a stock market bubble - Mark...
#
#                                               summary  \
# 0   <ol><li><a href="https://news.google.com/__i/r...
# 1   <a href="https://news.google.com/__i/rss/rd/ar...
# 2   <a href="https://news.google.com/__i/rss/rd/ar...
# 3   <a href="https://news.google.com/__i/rss/rd/ar...
# ...

# %%
df.columns
# Out:
# Index(['title', 'summary', 'published', 'link'], dtype='object')

# %%
a = df.link[3]

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
g_feed = url_to_string(a)
article = nlp(g_feed)
len(article.ents)
# Out:
# 143

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 50,
#          'GPE': 15,
#          'PERSON': 10,
#          'DATE': 24,
#          'PERCENT': 9,
#          'CARDINAL': 16,
#          'TIME': 9,
#          'NORP': 5,
#          'ORDINAL': 2,
#          'MONEY': 3})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Tuesday', 5), ('Tata Motors', 4), ('Axis Bank', 4)]

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">     Markets seen flat ahead of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US Fed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  meet;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tata Motors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Axis Bank
# ...
